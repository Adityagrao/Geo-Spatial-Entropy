# %%
import pandas as pd 
import numpy as np
from math import log

# %%
zomato_data = pd.read_csv('data/zomato.csv',encoding="ISO-8859-1")
country = pd.read_excel('data/Country-Code.xlsx')

# %%
data = pd.merge(zomato_data, country, on='Country Code')

# %%
india_data = data[data.Country == 'India']

# %%
india_data.head()
# Out:
#      Restaurant ID                        Restaurant Name  Country Code  City  \
# 624        3400025                             Jahanpanah             1  Agra
# 625        3400341                    Rangrezz Restaurant             1  Agra
# 626        3400005                Time2Eat - Mama Chicken             1  Agra
# 627        3400021  Chokho Jeeman Marwari Jain Bhojanalya             1  Agra
# 628        3400017                         Pinch Of Spice             1  Agra
#
#                                                Address     Locality  \
# 624  E 23, Shopping Arcade, Sadar Bazaar, Agra Cant...   Agra Cantt
# 625  E-20, Shopping Arcade, Sadar Bazaar, Agra Cant...   Agra Cantt
# 626        Main Market, Sadar Bazaar, Agra Cantt, Agra   Agra Cantt
# 627  1/48, Delhi Gate, Station Road, Raja Mandi, Ci...  Civil Lines
# 628  23/453, Opposite Sanjay Cinema, Wazipura Road,...  Civil Lines
#
#       Locality Verbose  Longitude   Latitude                        Cuisines  \
# ...

# %%
def entropy(labels, base=2):
    try:
        n_labels = len(labels)
        if n_labels <= 1:
            return 0
        value,counts = np.unique(labels, return_counts=True)
        probs = counts / n_labels
        n_classes = np.count_nonzero(probs)
        if n_classes <= 1:
            return 0
        ent = 0.
        # Compute entropy
        base = e if base is None else base
        for i in probs:
            ent -= i * log(i, base)
        return ent
    except:
        pass

# %%
ent = entropy((india_data['Longitude'],india_data['Latitude']))
print(f"Total Entropy = {ent}")
# Out:
# Total Entropy = 2128.8796035202904

# %%
for city in list(india_data.City.unique()):
    entropy_sum = np.nansum(entropy((india_data['Longitude'][india_data.City == city],india_data['Latitude'][india_data.City == city])))
    print(f"{city} - {entropy_sum} ")
# Out:
# Agra - -5.5097750043269365
# Ahmedabad - 21.0
# Allahabad - 3.3903595255631895
# Amritsar - 9.0
# Aurangabad - 8.0
# Bangalore - 20.0
# Bhopal - -1.5097750043269365
# Bhubaneshwar - 9.0
# Chandigarh - 17.0
# Chennai - 20.0
# Coimbatore - 20.0
# Dehradun - -6.651484454403228
# Faridabad - 100.51506063889774
# Ghaziabad - 23.0
# Goa - 12.24511249783653
# Gurgaon - 537.4549707680769
# Guwahati - -0.5097750043269365
# Hyderabad - 18.0
# Indore - 20.0
# Jaipur - 20.0
# Kanpur - 16.0
# Kochi - 20.0
# Kolkata - 20.0
# Lucknow - 9.0
# Ludhiana - 16.0
# Mangalore - -17.529325012980813
# Mohali - None
# Mumbai - 20.0
# Mysore - 19.0
# Nagpur - 19.0
# Nashik - -3.5097750043269365
# New Delhi - 2451.177208620212
# Noida - 70.27228337868465
# Panchkula - None
# Patna - 12.24511249783653
# Puducherry - 20.0
# Pune - 20.0
# Ranchi - 8.0
# Secunderabad - 2.0
# Surat - 20.0
# Vadodara - -23.219280948873624
# Varanasi - -8.651484454403228
# Vizag - 3.3903595255631895
